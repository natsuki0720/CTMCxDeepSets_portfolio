# %%
import sys
import os
sys.path.append(os.path.abspath("../"))  # or "../../" depending on location

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from utils.likelihood import *
from utils.formate_matrix_toMLData import *
from models.model_for_uniform_model import *
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.rcParams["font.size"] = 22
np.set_printoptions(suppress=True)

# %%
# load virtual data
data_dir = "../datas/for_uniform"
test_states = []
test_del_t = []
test_targets = []
dataset = []
data_formater = formate_dataMatrix()

def process_file(file_path):
    #ファイルの読み込み
    with open(file_path,encoding="utf-8-sig") as f:
        all_matrix = np.loadtxt(f, delimiter= ",")
    tm = matrix_trimer(all_matrix)
    trm = tm.trim_transitionRateMatrix()
    data = tm.trim_data()
    dataset.append(data)
    output_vec = np.array(data_formater.GetOutputVector_byDiagonal(trm))
    
    state = np.stack([data[:,0], data[:,1]], axis=0)
    test_states.append(state)
    
    test_del_t.append(data[:, 2])
    
    test_targets.append(output_vec)
    print(file_path)

data_formater.process_all_files_in_directory(data_dir,process_file)


# データセットとデータローダーの作成
test_dataset = varSets_Datasets(test_states, test_del_t, test_targets)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)
data_iter = iter(test_dataloader)
# Out:
# ../datas/for_uniform\0_30000_4.csv
# ../datas/for_uniform\100_30000_4.csv
# ../datas/for_uniform\101_30000_4.csv
# ../datas/for_uniform\102_30000_4.csv
# ../datas/for_uniform\103_30000_4.csv
# ../datas/for_uniform\104_30000_4.csv
# ../datas/for_uniform\105_30000_4.csv
# ../datas/for_uniform\106_30000_4.csv
# ../datas/for_uniform\107_30000_4.csv
# ../datas/for_uniform\108_30000_4.csv
# ../datas/for_uniform\109_30000_4.csv
# ../datas/for_uniform\10_30000_4.csv
# ../datas/for_uniform\110_30000_4.csv
# ../datas/for_uniform\111_30000_4.csv
# ../datas/for_uniform\112_30000_4.csv
# ../datas/for_uniform\113_30000_4.csv
# ../datas/for_uniform\114_30000_4.csv
# ../datas/for_uniform\115_30000_4.csv
# ../datas/for_uniform\116_30000_4.csv
# ../datas/for_uniform\117_30000_4.csv
# ../datas/for_uniform\118_30000_4.csv
# ../datas/for_uniform\119_30000_4.csv
# ../datas/for_uniform\11_30000_4.csv
# ../datas/for_uniform\120_30000_4.csv
# ../datas/for_uniform\121_30000_4.csv
# ../datas/for_uniform\122_30000_4.csv
# ../datas/for_uniform\123_30000_4.csv
# ../datas/for_uniform\124_30000_4.csv
# ../datas/for_uniform\125_30000_4.csv
# ../datas/for_uniform\126_30000_4.csv
# ../datas/for_uniform\127_30000_4.csv
# ../datas/for_uniform\128_30000_4.csv
# ../datas/for_uniform\129_30000_4.csv
# ../datas/for_uniform\12_30000_4.csv
# ../datas/for_uniform\130_30000_4.csv
# ../datas/for_uniform\131_30000_4.csv
# ../datas/for_uniform\132_30000_4.csv
# ../datas/for_uniform\133_30000_4.csv
# ../datas/for_uniform\134_30000_4.csv
# ../datas/for_uniform\135_30000_4.csv
# ../datas/for_uniform\136_30000_4.csv
# ../datas/for_uniform\137_30000_4.csv
# ../datas/for_uniform\138_30000_4.csv
# ../datas/for_uniform\139_30000_4.csv
# ../datas/for_uniform\13_30000_4.csv
# ../datas/for_uniform\140_30000_4.csv
# ../datas/for_uniform\141_30000_4.csv
# ../datas/for_uniform\142_30000_4.csv
# ../datas/for_uniform\143_30000_4.csv
# ../datas/for_uniform\144_30000_4.csv
# ../datas/for_uniform\145_30000_4.csv
# ../datas/for_uniform\146_30000_4.csv
# ../datas/for_uniform\147_30000_4.csv
# ../datas/for_uniform\148_30000_4.csv
# ../datas/for_uniform\149_30000_4.csv
# ../datas/for_uniform\14_30000_4.csv
# ../datas/for_uniform\150_30000_4.csv
# ../datas/for_uniform\151_30000_4.csv
# ../datas/for_uniform\152_30000_4.csv
# ../datas/for_uniform\153_30000_4.csv
# ../datas/for_uniform\154_30000_4.csv
# ../datas/for_uniform\155_30000_4.csv
# ../datas/for_uniform\156_30000_4.csv
# ../datas/for_uniform\157_30000_4.csv
# ../datas/for_uniform\158_30000_4.csv
# ../datas/for_uniform\159_30000_4.csv
# ../datas/for_uniform\15_30000_4.csv
# ../datas/for_uniform\160_30000_4.csv
# ../datas/for_uniform\161_30000_4.csv
# ../datas/for_uniform\162_30000_4.csv
# ../datas/for_uniform\163_30000_4.csv
# ../datas/for_uniform\164_30000_4.csv
# ../datas/for_uniform\165_30000_4.csv
# ../datas/for_uniform\166_30000_4.csv
# ../datas/for_uniform\167_30000_4.csv
# ../datas/for_uniform\168_30000_4.csv
# ../datas/for_uniform\169_30000_4.csv
# ../datas/for_uniform\16_30000_4.csv
# ../datas/for_uniform\170_30000_4.csv
# ../datas/for_uniform\171_30000_4.csv
# ../datas/for_uniform\172_30000_4.csv
# ../datas/for_uniform\173_30000_4.csv
# ../datas/for_uniform\174_30000_4.csv
# ../datas/for_uniform\175_30000_4.csv
# ../datas/for_uniform\176_30000_4.csv
# ../datas/for_uniform\177_30000_4.csv
# ../datas/for_uniform\178_30000_4.csv
# ../datas/for_uniform\179_30000_4.csv
# ../datas/for_uniform\17_30000_4.csv
# ../datas/for_uniform\180_30000_4.csv
# ../datas/for_uniform\181_30000_4.csv
# ../datas/for_uniform\182_30000_4.csv
# ../datas/for_uniform\183_30000_4.csv
# ../datas/for_uniform\184_30000_4.csv
# ../datas/for_uniform\185_30000_4.csv
# ../datas/for_uniform\186_30000_4.csv
# ../datas/for_uniform\187_30000_4.csv
# ../datas/for_uniform\188_30000_4.csv
# ../datas/for_uniform\189_30000_4.csv
# ../datas/for_uniform\18_30000_4.csv
# ../datas/for_uniform\190_30000_4.csv
# ../datas/for_uniform\191_30000_4.csv
# ../datas/for_uniform\192_30000_4.csv
# ../datas/for_uniform\193_30000_4.csv
# ../datas/for_uniform\194_30000_4.csv
# ../datas/for_uniform\195_30000_4.csv
# ../datas/for_uniform\196_30000_4.csv
# ../datas/for_uniform\197_30000_4.csv
# ../datas/for_uniform\198_30000_4.csv
# ../datas/for_uniform\199_30000_4.csv
# ../datas/for_uniform\19_30000_4.csv
# ../datas/for_uniform\1_30000_4.csv
# ../datas/for_uniform\200_30000_4.csv
# ../datas/for_uniform\201_30000_4.csv
# ../datas/for_uniform\202_30000_4.csv
# ../datas/for_uniform\203_30000_4.csv
# ../datas/for_uniform\204_30000_4.csv
# ../datas/for_uniform\205_30000_4.csv
# ../datas/for_uniform\206_30000_4.csv
# ../datas/for_uniform\207_30000_4.csv
# ../datas/for_uniform\208_30000_4.csv
# ../datas/for_uniform\209_30000_4.csv
# ../datas/for_uniform\20_30000_4.csv
# ../datas/for_uniform\210_30000_4.csv
# ../datas/for_uniform\211_30000_4.csv
# ../datas/for_uniform\212_30000_4.csv
# ../datas/for_uniform\213_30000_4.csv
# ../datas/for_uniform\214_30000_4.csv
# ../datas/for_uniform\215_30000_4.csv
# ../datas/for_uniform\216_30000_4.csv
# ../datas/for_uniform\217_30000_4.csv
# ../datas/for_uniform\218_30000_4.csv
# ../datas/for_uniform\219_30000_4.csv
# ../datas/for_uniform\21_30000_4.csv
# ../datas/for_uniform\220_30000_4.csv
# ../datas/for_uniform\221_30000_4.csv
# ../datas/for_uniform\222_30000_4.csv
# ../datas/for_uniform\223_30000_4.csv
# ../datas/for_uniform\224_30000_4.csv
# ../datas/for_uniform\225_30000_4.csv
# ../datas/for_uniform\226_30000_4.csv
# ../datas/for_uniform\227_30000_4.csv
# ../datas/for_uniform\228_30000_4.csv
# ../datas/for_uniform\229_30000_4.csv
# ../datas/for_uniform\22_30000_4.csv
# ../datas/for_uniform\230_30000_4.csv
# ../datas/for_uniform\231_30000_4.csv
# ../datas/for_uniform\232_30000_4.csv
# ../datas/for_uniform\233_30000_4.csv
# ../datas/for_uniform\234_30000_4.csv
# ../datas/for_uniform\235_30000_4.csv
# ../datas/for_uniform\236_30000_4.csv
# ../datas/for_uniform\237_30000_4.csv
# ../datas/for_uniform\238_30000_4.csv
# ../datas/for_uniform\239_30000_4.csv
# ../datas/for_uniform\23_30000_4.csv
# ../datas/for_uniform\240_30000_4.csv
# ../datas/for_uniform\241_30000_4.csv
# ../datas/for_uniform\242_30000_4.csv
# ../datas/for_uniform\243_30000_4.csv
# ../datas/for_uniform\244_30000_4.csv
# ../datas/for_uniform\245_30000_4.csv
# ../datas/for_uniform\246_30000_4.csv
# ../datas/for_uniform\247_30000_4.csv
# ../datas/for_uniform\248_30000_4.csv
# ../datas/for_uniform\249_30000_4.csv
# ../datas/for_uniform\24_30000_4.csv
# ../datas/for_uniform\250_30000_4.csv
# ../datas/for_uniform\251_30000_4.csv
# ../datas/for_uniform\252_30000_4.csv
# ../datas/for_uniform\253_30000_4.csv
# ../datas/for_uniform\254_30000_4.csv
# ../datas/for_uniform\255_30000_4.csv
# ../datas/for_uniform\256_30000_4.csv
# ../datas/for_uniform\257_30000_4.csv
# ../datas/for_uniform\258_30000_4.csv
# ../datas/for_uniform\259_30000_4.csv
# ../datas/for_uniform\25_30000_4.csv
# ../datas/for_uniform\260_30000_4.csv
# ../datas/for_uniform\261_30000_4.csv
# ../datas/for_uniform\262_30000_4.csv
# ../datas/for_uniform\263_30000_4.csv
# ../datas/for_uniform\264_30000_4.csv
# ../datas/for_uniform\265_30000_4.csv
# ../datas/for_uniform\266_30000_4.csv
# ../datas/for_uniform\267_30000_4.csv
# ../datas/for_uniform\268_30000_4.csv
# ../datas/for_uniform\269_30000_4.csv
# ../datas/for_uniform\26_30000_4.csv
# ../datas/for_uniform\270_30000_4.csv
# ../datas/for_uniform\271_30000_4.csv
# ../datas/for_uniform\272_30000_4.csv
# ../datas/for_uniform\273_30000_4.csv
# ../datas/for_uniform\274_30000_4.csv
# ../datas/for_uniform\275_30000_4.csv
# ../datas/for_uniform\276_30000_4.csv
# ../datas/for_uniform\277_30000_4.csv
# ../datas/for_uniform\278_30000_4.csv
# ../datas/for_uniform\279_30000_4.csv
# ../datas/for_uniform\27_30000_4.csv
# ../datas/for_uniform\280_30000_4.csv
# ../datas/for_uniform\281_30000_4.csv
# ../datas/for_uniform\282_30000_4.csv
# ../datas/for_uniform\283_30000_4.csv
# ../datas/for_uniform\284_30000_4.csv
# ../datas/for_uniform\285_30000_4.csv
# ../datas/for_uniform\286_30000_4.csv
# ../datas/for_uniform\287_30000_4.csv
# ../datas/for_uniform\288_30000_4.csv
# ../datas/for_uniform\289_30000_4.csv
# ../datas/for_uniform\28_30000_4.csv
# ../datas/for_uniform\290_30000_4.csv
# ../datas/for_uniform\291_30000_4.csv
# ../datas/for_uniform\292_30000_4.csv
# ../datas/for_uniform\293_30000_4.csv
# ../datas/for_uniform\294_30000_4.csv
# ../datas/for_uniform\295_30000_4.csv
# ../datas/for_uniform\296_30000_4.csv
# ../datas/for_uniform\297_30000_4.csv
# ../datas/for_uniform\298_30000_4.csv
# ../datas/for_uniform\299_30000_4.csv
# ../datas/for_uniform\29_30000_4.csv
# ../datas/for_uniform\2_30000_4.csv
# ../datas/for_uniform\300_30000_4.csv
# ../datas/for_uniform\301_30000_4.csv
# ../datas/for_uniform\302_30000_4.csv
# ../datas/for_uniform\303_30000_4.csv
# ../datas/for_uniform\304_30000_4.csv
# ../datas/for_uniform\305_30000_4.csv
# ../datas/for_uniform\306_30000_4.csv
# ../datas/for_uniform\307_30000_4.csv
# ../datas/for_uniform\308_30000_4.csv
# ../datas/for_uniform\309_30000_4.csv
# ../datas/for_uniform\30_30000_4.csv
# ../datas/for_uniform\310_30000_4.csv
# ../datas/for_uniform\311_30000_4.csv
# ../datas/for_uniform\312_30000_4.csv
# ../datas/for_uniform\313_30000_4.csv
# ../datas/for_uniform\314_30000_4.csv
# ../datas/for_uniform\315_30000_4.csv
# ../datas/for_uniform\316_30000_4.csv
# ../datas/for_uniform\317_30000_4.csv
# ../datas/for_uniform\318_30000_4.csv
# ../datas/for_uniform\319_30000_4.csv
# ../datas/for_uniform\31_30000_4.csv
# ../datas/for_uniform\320_30000_4.csv
# ../datas/for_uniform\321_30000_4.csv
# ../datas/for_uniform\322_30000_4.csv
# ../datas/for_uniform\323_30000_4.csv
# ../datas/for_uniform\324_30000_4.csv
# ../datas/for_uniform\325_30000_4.csv
# ../datas/for_uniform\326_30000_4.csv
# ../datas/for_uniform\327_30000_4.csv
# ../datas/for_uniform\328_30000_4.csv
# ../datas/for_uniform\329_30000_4.csv
# ../datas/for_uniform\32_30000_4.csv
# ../datas/for_uniform\330_30000_4.csv
# ../datas/for_uniform\331_30000_4.csv
# ../datas/for_uniform\332_30000_4.csv
# ../datas/for_uniform\333_30000_4.csv
# ../datas/for_uniform\334_30000_4.csv
# ../datas/for_uniform\335_30000_4.csv
# ../datas/for_uniform\336_30000_4.csv
# ../datas/for_uniform\337_30000_4.csv
# ../datas/for_uniform\338_30000_4.csv
# ../datas/for_uniform\339_30000_4.csv
# ../datas/for_uniform\33_30000_4.csv
# ../datas/for_uniform\340_30000_4.csv
# ../datas/for_uniform\341_30000_4.csv
# ../datas/for_uniform\342_30000_4.csv
# ../datas/for_uniform\343_30000_4.csv
# ../datas/for_uniform\344_30000_4.csv
# ../datas/for_uniform\345_30000_4.csv
# ../datas/for_uniform\346_30000_4.csv
# ../datas/for_uniform\347_30000_4.csv
# ../datas/for_uniform\348_30000_4.csv
# ../datas/for_uniform\349_30000_4.csv
# ../datas/for_uniform\34_30000_4.csv
# ../datas/for_uniform\350_30000_4.csv
# ../datas/for_uniform\351_30000_4.csv
# ../datas/for_uniform\352_30000_4.csv
# ../datas/for_uniform\353_30000_4.csv
# ../datas/for_uniform\354_30000_4.csv
# ../datas/for_uniform\355_30000_4.csv
# ../datas/for_uniform\356_30000_4.csv
# ../datas/for_uniform\357_30000_4.csv
# ../datas/for_uniform\358_30000_4.csv
# ../datas/for_uniform\359_30000_4.csv
# ../datas/for_uniform\35_30000_4.csv
# ../datas/for_uniform\360_30000_4.csv
# ../datas/for_uniform\361_30000_4.csv
# ../datas/for_uniform\362_30000_4.csv
# ../datas/for_uniform\363_30000_4.csv
# ../datas/for_uniform\364_30000_4.csv
# ../datas/for_uniform\365_30000_4.csv
# ../datas/for_uniform\366_30000_4.csv
# ../datas/for_uniform\367_30000_4.csv
# ../datas/for_uniform\368_30000_4.csv
# ../datas/for_uniform\369_30000_4.csv
# ../datas/for_uniform\36_30000_4.csv
# ../datas/for_uniform\370_30000_4.csv
# ../datas/for_uniform\371_30000_4.csv
# ../datas/for_uniform\372_30000_4.csv
# ../datas/for_uniform\373_30000_4.csv
# ../datas/for_uniform\374_30000_4.csv
# ../datas/for_uniform\375_30000_4.csv
# ../datas/for_uniform\376_30000_4.csv
# ../datas/for_uniform\377_30000_4.csv
# ../datas/for_uniform\378_30000_4.csv
# ../datas/for_uniform\379_30000_4.csv
# ../datas/for_uniform\37_30000_4.csv
# ../datas/for_uniform\380_30000_4.csv
# ../datas/for_uniform\381_30000_4.csv
# ../datas/for_uniform\382_30000_4.csv
# ../datas/for_uniform\383_30000_4.csv
# ../datas/for_uniform\384_30000_4.csv
# ../datas/for_uniform\385_30000_4.csv
# ../datas/for_uniform\386_30000_4.csv
# ../datas/for_uniform\387_30000_4.csv
# ../datas/for_uniform\388_30000_4.csv
# ../datas/for_uniform\389_30000_4.csv
# ../datas/for_uniform\38_30000_4.csv
# ../datas/for_uniform\390_30000_4.csv
# ../datas/for_uniform\391_30000_4.csv
# ../datas/for_uniform\392_30000_4.csv
# ../datas/for_uniform\393_30000_4.csv
# ../datas/for_uniform\394_30000_4.csv
# ../datas/for_uniform\395_30000_4.csv
# ../datas/for_uniform\396_30000_4.csv
# ../datas/for_uniform\397_30000_4.csv
# ../datas/for_uniform\398_30000_4.csv
# ../datas/for_uniform\399_30000_4.csv
# ../datas/for_uniform\39_30000_4.csv
# ../datas/for_uniform\3_30000_4.csv
# ../datas/for_uniform\400_30000_4.csv
# ../datas/for_uniform\401_30000_4.csv
# ../datas/for_uniform\402_30000_4.csv
# ../datas/for_uniform\403_30000_4.csv
# ../datas/for_uniform\404_30000_4.csv
# ../datas/for_uniform\405_30000_4.csv
# ../datas/for_uniform\406_30000_4.csv
# ../datas/for_uniform\407_30000_4.csv
# ../datas/for_uniform\408_30000_4.csv
# ../datas/for_uniform\409_30000_4.csv
# ../datas/for_uniform\40_30000_4.csv
# ../datas/for_uniform\410_30000_4.csv
# ../datas/for_uniform\411_30000_4.csv
# ../datas/for_uniform\412_30000_4.csv
# ../datas/for_uniform\413_30000_4.csv
# ../datas/for_uniform\414_30000_4.csv
# ../datas/for_uniform\415_30000_4.csv
# ../datas/for_uniform\416_30000_4.csv
# ../datas/for_uniform\417_30000_4.csv
# ../datas/for_uniform\418_30000_4.csv
# ../datas/for_uniform\419_30000_4.csv
# ../datas/for_uniform\41_30000_4.csv
# ../datas/for_uniform\420_30000_4.csv
# ../datas/for_uniform\421_30000_4.csv
# ../datas/for_uniform\422_30000_4.csv
# ../datas/for_uniform\423_30000_4.csv
# ../datas/for_uniform\424_30000_4.csv
# ../datas/for_uniform\425_30000_4.csv
# ../datas/for_uniform\426_30000_4.csv
# ../datas/for_uniform\427_30000_4.csv
# ../datas/for_uniform\428_30000_4.csv
# ../datas/for_uniform\429_30000_4.csv
# ../datas/for_uniform\42_30000_4.csv
# ../datas/for_uniform\430_30000_4.csv
# ../datas/for_uniform\431_30000_4.csv
# ../datas/for_uniform\432_30000_4.csv
# ../datas/for_uniform\433_30000_4.csv
# ../datas/for_uniform\434_30000_4.csv
# ../datas/for_uniform\435_30000_4.csv
# ../datas/for_uniform\436_30000_4.csv
# ../datas/for_uniform\437_30000_4.csv
# ../datas/for_uniform\438_30000_4.csv
# ../datas/for_uniform\439_30000_4.csv
# ../datas/for_uniform\43_30000_4.csv
# ../datas/for_uniform\440_30000_4.csv
# ../datas/for_uniform\441_30000_4.csv
# ../datas/for_uniform\442_30000_4.csv
# ../datas/for_uniform\443_30000_4.csv
# ../datas/for_uniform\444_30000_4.csv
# ../datas/for_uniform\445_30000_4.csv
# ../datas/for_uniform\446_30000_4.csv
# ../datas/for_uniform\447_30000_4.csv
# ../datas/for_uniform\448_30000_4.csv
# ../datas/for_uniform\449_30000_4.csv
# ../datas/for_uniform\44_30000_4.csv
# ../datas/for_uniform\450_30000_4.csv
# ../datas/for_uniform\451_30000_4.csv
# ../datas/for_uniform\452_30000_4.csv
# ../datas/for_uniform\453_30000_4.csv
# ../datas/for_uniform\454_30000_4.csv
# ../datas/for_uniform\455_30000_4.csv
# ../datas/for_uniform\456_30000_4.csv
# ../datas/for_uniform\457_30000_4.csv
# ../datas/for_uniform\458_30000_4.csv
# ../datas/for_uniform\459_30000_4.csv
# ../datas/for_uniform\45_30000_4.csv
# ../datas/for_uniform\460_30000_4.csv
# ../datas/for_uniform\461_30000_4.csv
# ../datas/for_uniform\462_30000_4.csv
# ../datas/for_uniform\463_30000_4.csv
# ../datas/for_uniform\464_30000_4.csv
# ../datas/for_uniform\465_30000_4.csv
# ../datas/for_uniform\466_30000_4.csv
# ../datas/for_uniform\467_30000_4.csv
# ../datas/for_uniform\468_30000_4.csv
# ../datas/for_uniform\469_30000_4.csv
# ../datas/for_uniform\46_30000_4.csv
# ../datas/for_uniform\470_30000_4.csv
# ../datas/for_uniform\471_30000_4.csv
# ../datas/for_uniform\472_30000_4.csv
# ../datas/for_uniform\473_30000_4.csv
# ../datas/for_uniform\474_30000_4.csv
# ../datas/for_uniform\475_30000_4.csv
# ../datas/for_uniform\476_30000_4.csv
# ../datas/for_uniform\477_30000_4.csv
# ../datas/for_uniform\478_30000_4.csv
# ../datas/for_uniform\479_30000_4.csv
# ../datas/for_uniform\47_30000_4.csv
# ../datas/for_uniform\480_30000_4.csv
# ../datas/for_uniform\481_30000_4.csv
# ../datas/for_uniform\482_30000_4.csv
# ../datas/for_uniform\483_30000_4.csv
# ../datas/for_uniform\484_30000_4.csv
# ../datas/for_uniform\485_30000_4.csv
# ../datas/for_uniform\486_30000_4.csv
# ../datas/for_uniform\487_30000_4.csv
# ../datas/for_uniform\488_30000_4.csv
# ../datas/for_uniform\489_30000_4.csv
# ../datas/for_uniform\48_30000_4.csv
# ../datas/for_uniform\490_30000_4.csv
# ../datas/for_uniform\491_30000_4.csv
# ../datas/for_uniform\492_30000_4.csv
# ../datas/for_uniform\493_30000_4.csv
# ../datas/for_uniform\494_30000_4.csv
# ../datas/for_uniform\495_30000_4.csv
# ../datas/for_uniform\496_30000_4.csv
# ../datas/for_uniform\497_30000_4.csv
# ../datas/for_uniform\498_30000_4.csv
# ../datas/for_uniform\499_30000_4.csv
# ../datas/for_uniform\49_30000_4.csv
# ../datas/for_uniform\4_30000_4.csv
# ../datas/for_uniform\50_30000_4.csv
# ../datas/for_uniform\51_30000_4.csv
# ../datas/for_uniform\52_30000_4.csv
# ../datas/for_uniform\53_30000_4.csv
# ../datas/for_uniform\54_30000_4.csv
# ../datas/for_uniform\55_30000_4.csv
# ../datas/for_uniform\56_30000_4.csv
# ../datas/for_uniform\57_30000_4.csv
# ../datas/for_uniform\58_30000_4.csv
# ../datas/for_uniform\59_30000_4.csv
# ../datas/for_uniform\5_30000_4.csv
# ../datas/for_uniform\60_30000_4.csv
# ../datas/for_uniform\61_30000_4.csv
# ../datas/for_uniform\62_30000_4.csv
# ../datas/for_uniform\63_30000_4.csv
# ../datas/for_uniform\64_30000_4.csv
# ../datas/for_uniform\65_30000_4.csv
# ../datas/for_uniform\66_30000_4.csv
# ../datas/for_uniform\67_30000_4.csv
# ../datas/for_uniform\68_30000_4.csv
# ../datas/for_uniform\69_30000_4.csv
# ../datas/for_uniform\6_30000_4.csv
# ../datas/for_uniform\70_30000_4.csv
# ../datas/for_uniform\71_30000_4.csv
# ../datas/for_uniform\72_30000_4.csv
# ../datas/for_uniform\73_30000_4.csv
# ../datas/for_uniform\74_30000_4.csv
# ../datas/for_uniform\75_30000_4.csv
# ../datas/for_uniform\76_30000_4.csv
# ../datas/for_uniform\77_30000_4.csv
# ../datas/for_uniform\78_30000_4.csv
# ../datas/for_uniform\79_30000_4.csv
# ../datas/for_uniform\7_30000_4.csv
# ../datas/for_uniform\80_30000_4.csv
# ../datas/for_uniform\81_30000_4.csv
# ../datas/for_uniform\82_30000_4.csv
# ../datas/for_uniform\83_30000_4.csv
# ../datas/for_uniform\84_30000_4.csv
# ../datas/for_uniform\85_30000_4.csv
# ../datas/for_uniform\86_30000_4.csv
# ../datas/for_uniform\87_30000_4.csv
# ../datas/for_uniform\88_30000_4.csv
# ../datas/for_uniform\89_30000_4.csv
# ../datas/for_uniform\8_30000_4.csv
# ../datas/for_uniform\90_30000_4.csv
# ../datas/for_uniform\91_30000_4.csv
# ../datas/for_uniform\92_30000_4.csv
# ../datas/for_uniform\93_30000_4.csv
# ../datas/for_uniform\94_30000_4.csv
# ../datas/for_uniform\95_30000_4.csv
# ../datas/for_uniform\96_30000_4.csv
# ../datas/for_uniform\97_30000_4.csv
# ../datas/for_uniform\98_30000_4.csv
# ../datas/for_uniform\99_30000_4.csv
# ../datas/for_uniform\9_30000_4.csv

# %%
# load model
model = DeepSets_varSets_forDiagnel()
model.load_state_dict(torch.load("../model_weights/uniform_distributed_delT/model_weights.pth"))
model.eval()
# Out:
# DeepSets_varSets_forDiagnel(
#   (embedding): Embedding(4, 2)
#   (fc1): Linear(in_features=5, out_features=64, bias=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=32, out_features=128, bias=True)
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (dropout4): Dropout(p=0.2, inplace=False)
#   (fc5): Linear(in_features=64, out_features=32, bias=True)
#   (dropout5): Dropout(p=0.1, inplace=False)
#   (fc6): Linear(in_features=32, out_features=3, bias=True)
# )

# %%
loss_list = []
outs_lifespan = []
true_lifespan = []
class all_lifespan_loss(nn.Module):
    def forward(self, outputs, targets):
        epsilon = 1e-12
        y_pred_inverse = 1.0 / (outputs + epsilon)
        y_true_inverse = 1.0 / (targets + epsilon)
        
        # 逆数の差の絶対値
        loss_tensor = torch.abs(y_pred_inverse - y_true_inverse)[0]
        return loss_tensor, y_true_inverse[0], y_pred_inverse
criterion = all_lifespan_loss()

for a, b, c,d in data_iter:
    with torch.no_grad():
        out = model(a, b, d)[0]
        loss, true_expect ,pred_expect= criterion(out,c)
        
        for i in range(3):
            true_lifespan.append(true_expect[i].item())
            outs_lifespan.append(pred_expect[i].item())

df = pd.DataFrame()
df["true"] = true_lifespan
df["pred"] = outs_lifespan
df["loss"] = (df["true"] - df["pred"]).abs()

# %%
plt.figure(figsize=(6,6))
x = np.linspace(0, 100, 1000)

plt.xlim(0,100)
plt.ylim(0,100)
plt.xlabel("最尤推定による期待寿命（年）")
plt.ylabel("代理モデルの推定期待寿命（年）")
plt.plot(x,x,color="#000000", linestyle = '--',zorder= 0)
plt.scatter(df["true"],df["pred"],color = "#d69c6a",edgecolors="#d79e6b",s = 20,  zorder= 1)

# %%
# verificate on real data（橋梁RC床版使用）(現状1.2がベスト)
real_data_dir = "../real_data/data.csv"
df = pd.read_csv(real_data_dir, delimiter=",", header = None)
df.columns = ["pre", "post", "time"]
df = df[df["pre"] < 4]
df = df[df["post"] < 5]
print(len(df))
r = 1.2
plt.hist(df["time"], bins=30, alpha=0.5, color="blue", edgecolor="black", zorder= 2)
plt.title("RC床版の点検間隔分布")
# Out:
# 5412
# Text(0.5, 1.0, 'RC床版の点検間隔分布')

# %%
# likelihood process
state = np.array([df["pre"],df["post"]])
del_t = np.array(df["time"]/r)

data = np.column_stack((state.T,del_t.T))
ll = Likelihood_diagonal_exp(data)
Q = ll.optimize(np.array([-0.5,-1,-1.5]))
formater = formate_dataMatrix()
vec = formater.GetOutputVector_byDiagonal(Q)

# %%
dataset = varSets_Datasets([state],[del_t], [vec])
dataloader = DataLoader(dataset, batch_size=1,shuffle=False,collate_fn=collate_fn)
pred = []
expect = []
for a, b, c,d in dataloader:
    with torch.no_grad():
        out = model(a, b, d)
        pred = 1/out
        expect = 1/c    
    print(f"output is {out}")
    print(f"target is {c}")
    print(1/out)
    print(1/c)
# Out:
# output is tensor([[0.0939, 0.0248, 0.0170]])
# target is tensor([[0.1044, 0.0220, 0.0321]])
# tensor([[10.6492, 40.3478, 58.9132]])
# tensor([[ 9.5796, 45.3648, 31.1287]])

# %%
colors= ['#6b89a9', '#8ea978', '#d69c6a', '#a55a5b'] #彩度下げ冷暖色
plt.rcParams["figure.figsize"] = (8, 5)

sequence = np.arange(0, 100, 0.01)
def visualize(Q,title):
    vecs = []
    for t in sequence:
        P = expm(Q * t)
        vecs.append(P[0])
    
    for i, vec in enumerate(vecs):
        bottom = 0
        # vec = vec[::-1]
    
        for j, value in enumerate(vec):
            plt.bar(sequence[i], value, bottom=bottom, color=colors[j],width=0.01)
            bottom += value
    for i in range(len(colors)):
        plt.scatter([],[], color = colors[i],label = f"Condition state {i+1}")
    vecs = np.array(vecs)
    
    plot_trueline(c[0])
    plt.tick_params(axis='x', labelsize=14, direction='in', length=10)
    plt.tick_params(axis='y', labelsize=14, direction='in', length=10)
    plt.xlabel("Elapsed time (year)", fontsize = 22)
    plt.ylabel("Ratio", fontsize = 22)
    # plt.title(title, fontsize = 18)
    plt.legend(loc = "lower left")
    plt.show()
    
def generate_Q_from_diagonal(vec):
        Q = np.zeros((4,4))
        for i in range(len(vec)):
            Q[i,i+1]= vec[i]
            Q[i,i] = -Q[i,i+1]
        return Q
def plot_trueline(vec):
    true_vecs = []
    true_Q = generate_Q_from_diagonal(vec/r)
    for t in sequence:
        P = expm(true_Q * t)
        true_vecs.append(P[0])
    true_vecs = np.array(true_vecs)
    
    plt.plot(sequence,true_vecs[:,0],linestyle = "--",color = "black",lw = 4)
    plt.plot(sequence,true_vecs[:,0]+true_vecs[:,1],linestyle = "-.",color = "black",lw = 4)
    plt.plot(sequence,true_vecs[:,0]+true_vecs[:,1]+true_vecs[:,2],linestyle = ":",color = "black",lw = 4)
    

print("代理モデルによる劣化推移予測")
visualize(generate_Q_from_diagonal(out[0]/r),"代理モデルによる劣化推移予測")
# Out:
# 代理モデルによる劣化推移予測
